# %% [markdown]
# # Download your model

# %%
from huggingface_hub import snapshot_download

HF_TOKEN = "hf_XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" 
snapshot_download(
    "google/functiongemma-270m-it",
    local_dir="./functiongemma-270m-it-v2",
    local_dir_use_symlinks=False,
    token=HF_TOKEN
)
# Out:
# Fetching 12 files: 100%|██████████| 12/12 [02:55<00:00, 14.63s/it]
# '/mnt/c/Users/suraj/MyWorkplace/AI/models/functiongemma-270m-it-v2'

# %% [markdown]
# DO NOT MESS UP WITH ENVIRONMENTs
# > I mean linux/windows 🥲
